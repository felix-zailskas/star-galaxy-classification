# %%
import cv2
import numpy as np
from astropy.coordinates import SkyCoord
from astropy.io import fits
from astropy.wcs import WCS
from matplotlib import pyplot as plt

# %%
# Provide the file paths of the spectral band files
file_paths = [
    "../data/008162-6-0080/frame-i-008162-6-0080.fits.bz2",
    "../data/008162-6-0080/frame-r-008162-6-0080.fits.bz2",
    "../data/008162-6-0080/frame-g-008162-6-0080.fits.bz2",
    "../data/008162-6-0080/frame-u-008162-6-0080.fits.bz2",
    "../data/008162-6-0080/frame-z-008162-6-0080.fits.bz2",
]

# %%
from alignment import align_image_channels

channels, cutoffs = align_image_channels(file_paths)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 55153.000000 from DATE-OBS'. [astropy.wcs.wcs]

# %%
print(cutoffs)

print(channels.shape)
idx_show = np.array([0,1,2])
print(channels.max())
print(channels.min())
plt.imshow(channels[:,:,idx_show])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (3, -1, 3, -10)
# (1476, 2044, 5)
# 1699.375
# -0.845306396484375

# %%
flipped_img = cv2.flip(channels, 0)
show = np.array([0,1,2])
print(flipped_img.shape)
plt.imshow(flipped_img[:,:,show])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1476, 2044, 5)

# %%
# Provide the file paths of the spectral band files
file_paths = [
    "../data/001006-6-0011/frame-i-001006-6-0011.fits.bz2",
    "../data/001006-6-0011/frame-r-001006-6-0011.fits.bz2",
    "../data/001006-6-0011/frame-g-001006-6-0011.fits.bz2",
    "../data/001006-6-0011/frame-u-001006-6-0011.fits.bz2",
    "../data/001006-6-0011/frame-z-001006-6-0011.fits.bz2",
]

from alignment import align_image_channels

channels, cutoffs = align_image_channels(file_paths)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51458.000000 from DATE-OBS'. [astropy.wcs.wcs]

# %%
print(cutoffs)

print(channels.shape)
idx_show = np.array([0,1,2])
print(channels.max())
print(channels.min())
plt.imshow(channels[:,:,idx_show])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (3, -4, 4, -11)
# (1474, 2041, 5)
# 258.212890625
# -0.4763219356536865
