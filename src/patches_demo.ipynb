# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
file_to_use = "008162-6-0080"

reference_img = f"../data/{file_to_use}/frame-i-{file_to_use}.fits.bz2"


m = scipy.io.loadmat(f"../data/processed/{file_to_use}.mat")
img = m["image"]
stars = m["stars"]
gals = m["galaxies"]

# %%
from preparation import create_image_patches

patches = create_image_patches(
    img, stars, gals, (64, 64), reference_img#, test_img
)

# %%
len(patches)
# Out:
# 713

# %%
from preparation import display_patches

display_patches(patches, 23, 31)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
from preparation import create_seg_map_from_patch
idx = 51
seg_map = create_seg_map_from_patch(patches[idx][0], patches[idx][1], patches[idx][2])

# %%
p, s, g = patches[idx]
plt.imshow(p[:, :, :3])
plt.scatter(s[:, 0], s[:, 1], color="green", s=1, label="Stars")
plt.scatter(g[:, 0], g[:, 1], color="blue", s=1, label="Galaxies")
plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 63.5, 63.5, -0.5)

# %%
plt.imshow(seg_map)
plt.axis("off")
# Out:
# (-0.5, 63.5, 63.5, -0.5)
